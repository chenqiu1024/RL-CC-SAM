# %%
DRIVE_ROOT_PATH = '/content/drive/MyDrive'
RLCCSAM_ROOT_PATH = f"{DRIVE_ROOT_PATH}/RL-CC-SAM"

# %%
from google.colab import drive
drive.mount("/content/drive")
## Ref: https://netraneupane.medium.com/how-to-install-libraries-permanently-in-google-colab-fb15a585d8a5

# %%
# !git clone https://github.com/chenqiu1024/RL-CC-SAM.git {RLCCSAM_ROOT_PATH}/

# %%
import os
os.chdir(RLCCSAM_ROOT_PATH)
# !echo `pwd`

# %%
# !tar -xf {DRIVE_ROOT_PATH}/datasets/MSD/Task01_BrainTumour.tar -C {RLCCSAM_ROOT_PATH}/datasets/nnUNet_raw/

# %%
# !git submodule update --init --recursive

# %%
# !source {DRIVE_ROOT_PATH}/colab_envs/llms/bin/activate && pip install -r requirements.txt

# %%
import os
# from pathlib import Path
# # Auto-detect project structure
# notebook_path = Path.cwd()
# if 'notebooks' in notebook_path.parts:
#     project_root = notebook_path.parent
# else:
#     project_root = notebook_path
# # Set nnU-Net environment
# datasets_path = project_root / "datasets"

os.environ.update({
    'nnUNet_raw': f"{RLCCSAM_ROOT_PATH}/datasets/nnUNet_raw",
    'nnUNet_preprocessed': f"{RLCCSAM_ROOT_PATH}/datasets/nnUNet_preprocessed",
    'nnUNet_results': f"{RLCCSAM_ROOT_PATH}/datasets/nnUNet_results"
})
print("🚀 nnU-Net environment ready!")

# %%
# 3. Verify setup works
# !nnUNetv2_plan_and_preprocess -h  # Should run without warnings

# %%
# !ls {DRIVE_ROOT_PATH}/datasets/
# !nnUNetv2_convert_MSD_dataset -h

# %%
import getpass
from google.colab import userdata
github_token = userdata.get('GITHUB_TOKEN')
##token = getpass.getpass('GITHUB_TOKEN')
print(github_token)

# %%
# !git status

# %%
# !git config --global user.email godspeed1024@hotmail.com
# !git config --global user.name chenqiu1024

# %%
# !git rm --cached notebooks/bash_playground.ipynb

# %%
# !git commit --amend -am "Use github_token to push"

# %%
from google.colab import userdata
import os

# Get token from Colab secrets
github_token = 'GITHUB_TOKEN_HERE'
print(github_token)
# # Configure git
# !git config --global user.email "your-email@example.com"
# !git config --global user.name "Your Name"

# # Clone repository
# !git remote set-url origin https://{github_token}@github.com/chenqiu1024/RL-CC-SAM.git
# !git clone {repo_url}

# # Navigate to repo and make changes
# os.chdir('/content/repo-name')

# # Push changes
# !git add .
# !git commit -m "Update from Colab"
# !git push origin main
