# %% [markdown]
# # Set-up environment

# %%
## Google Drive root path and project path definitions
DRIVE_ROOT_PATH = '/content/drive/MyDrive'
PROJECT_ROOT = f"{DRIVE_ROOT_PATH}/RL-CC-SAM"

# %%
## Mount Google Drive
from google.colab import drive
drive.mount("/content/drive")
## Ref: https://netraneupane.medium.com/how-to-install-libraries-permanently-in-google-colab-fb15a585d8a5
# Out:
# Mounted at /content/drive

# %%
import os
import sys
from pathlib import Path

os.chdir(PROJECT_ROOT)
sys.path.append(PROJECT_ROOT)

SEGMENT_ANYTHING_DIR = Path(PROJECT_ROOT) / "segment-anything"
sys.path.append(str(SEGMENT_ANYTHING_DIR))

# %%
# !source {DRIVE_ROOT_PATH}/colab_envs/llms/bin/activate && python -m pip install -q git+https://github.com/huggingface/transformers.git datasets
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done

# %%
# !source {DRIVE_ROOT_PATH}/colab_envs/llms/bin/activate && python -m pip install accelerate==0.20.3
# !source {DRIVE_ROOT_PATH}/colab_envs/llms/bin/activate && python -m pip install pymatreader
# Out:
# Collecting accelerate==0.20.3
#   Downloading accelerate-0.20.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from accelerate==0.20.3) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from accelerate==0.20.3) (25.0)
# Requirement already satisfied: psutil in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from accelerate==0.20.3) (7.0.0)
# Requirement already satisfied: pyyaml in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from accelerate==0.20.3) (6.0.2)
# Requirement already satisfied: torch>=1.6.0 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from accelerate==0.20.3) (2.7.1)
# Requirement already satisfied: filelock in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (1.14.0)
# Requirement already satisfied: networkx in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.5)
# Requirement already satisfied: jinja2 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.1.6)
# Requirement already satisfied: fsspec in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from triton==3.3.1->torch>=1.6.0->accelerate==0.20.3) (80.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.6.0->accelerate==0.20.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->accelerate==0.20.3) (3.0.2)
# Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.8.1
#     Uninstalling accelerate-1.8.1:
#       Successfully uninstalled accelerate-1.8.1
# Successfully installed accelerate-0.20.3
# Requirement already satisfied: pymatreader in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: h5py in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from pymatreader) (3.14.0)
# Requirement already satisfied: numpy in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from pymatreader) (2.2.6)
# Requirement already satisfied: scipy>=1.7.1 in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from pymatreader) (1.15.3)
# Requirement already satisfied: xmltodict in /content/drive/MyDrive/colab_envs/llms/lib/python3.11/site-packages (from pymatreader) (0.14.2)

# %% [markdown]
# # Load model and processor

# %%
import torch
from transformers import SamModel, SamProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"

processor = SamProcessor.from_pretrained("wanglab/medsam-vit-base")
model = SamModel.from_pretrained("wanglab/medsam-vit-base").to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/6.52k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/375M [00:00<?, ?B/s]

# %%
from datasets import load_dataset

dataset = load_dataset("nielsr/breast-cancer", split="train")
# Out:
# Downloading and preparing dataset parquet/nielsr--breast-cancer to /root/.cache/huggingface/datasets/parquet/nielsr--breast-cancer-c16ee7932c43ffa3/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/10.0M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/parquet/nielsr--breast-cancer-c16ee7932c43ffa3/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901. Subsequent calls will reuse this data.

# %% [markdown]
# # Define Metrics

# %%
def DICE_COE(mask1, mask2):
    intersect = np.sum(mask1*mask2)
    fsum = np.sum(mask1)
    ssum = np.sum(mask2)
    dice = (2 * intersect ) / (fsum + ssum)
    dice = np.mean(dice)
    dice = round(dice, 3) # for easy reading
    return dice

def mean_pixel_accuracy(pixel_correct, pixel_labeled):
    mean_pixel_accuracy = 1.0 * np.sum(pixel_correct) / (np.spacing(1) + np.sum(pixel_labeled))
    mean_pixel_accuracy = round(mean_pixel_accuracy,2)
    return mean_pixel_accuracy

def compute_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    iou = round(iou, 2)
    return iou

def filter_masks(mask_array1, mask_array2, threshold):
    return np.array([mask1 for mask1 in mask_array1 if max(compute_iou(mask1, mask2) for mask2 in mask_array2) < threshold])

# %% [markdown]
# # Load model and processor

# %%
import torch
from transformers import SamModel, SamProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"

processor = SamProcessor.from_pretrained("wanglab/medsam-vit-base")
model = SamModel.from_pretrained("wanglab/medsam-vit-base").to(device)

# %% [markdown]
# # Load image + ground truth map

# %%
import os
import cv2
import torch
import base64
import nibabel as nib
import glob
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
raw_data = pd.read_csv('/kaggle/input/covid19-ct-scans/metadata.csv')

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    filepath = filepath.replace('..','')
    ct_scan = nib.load('/kaggle/' + filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# %%
import cv2
import numpy as np
dataimg = sample_ct[...,125]
dataall = sample_all[...,125]
dataall = 255 * dataall
dataimg = 255 * dataimg # Now scale by 255
img = dataimg.astype(np.uint8)
iall = dataall.astype(np.uint8)
data1 = Image.fromarray(img)
data2= Image.fromarray(iall)
data3 = Image.blend(data1, data2, 0.55)

# %%
plt.imshow(sample_ct[...,125],cmap='bone')
plt.imshow(sample_all[...,125], alpha=0.5, cmap='nipy_spectral')

# %%
data3
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
image_data = np.asarray(data3)

# %%
image = image_data

# %%
image = cv2.imread("/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/COVID/images/COVID-1.png")

# %%
image = cv2.resize(image,(256,256))

# %%
image.shape
# Out:
# (256, 256, 3)

# %%
# !mkdir -p data
data1.save(f"data/main.png")
data3.save(f'data/infection.png')
# !ls -lh data
# Out:
# total 476K
# -rw-r--r-- 1 root root 225K Jul 19 05:40 infection.png
# -rw-r--r-- 1 root root 248K Jul 19 05:40 main.png

# %%
# from datasets import load_dataset

# dataset = load_dataset("nielsr/breast-cancer", split="train")

# %%
data1
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
# import numpy as np
# from PIL import Image

# idx = 10

# # load image
# image = dataset[idx]["image"]
# image

# %%
from skimage import io
from skimage import data
from skimage.color import rgb2gray
from skimage import data
from pymatreader import read_mat

# %%
# data_label = read_mat("/kaggle/input/hovernetdataset/cpm/kumar/test_diff/Labels/TCGA-AY-A8YK-01A-01-TS1.mat")
# data_label2 = Image.fromarray(data['inst_map'][:,:])

# %%
# load ground truth segmentation
ground_truth_seg = np.array(dataset[idx]["label"])
np.unique(ground_truth_seg)
# Out:
# array([0, 1], dtype=int32)

# %%
# ground_truth_seg = data2

# %%
ground_truth_seg = iall

# %%
ground_truth_seg = cv2.imread('/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/COVID/masks/COVID-1.png')

# %%
ground_truth_seg= ground_truth_seg[:,:,0]

# %%
ground_truth_seg.shape
# Out:
# (256, 256)

# %%
# a random color palette mapping each class to a color (RGB)
palette = [[120, 120, 120], [6, 230, 230]]

color_seg = np.zeros((ground_truth_seg.shape[0], ground_truth_seg.shape[1], 3), dtype=np.uint8) # height, width, 3

for label, color in enumerate(palette):
    color_seg[ground_truth_seg == label, :] = color

Image.fromarray(color_seg)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
ground_truth_seg.shape
# Out:
# (256, 256)

# %% [markdown]
# # Load box prompt and predict

# %%
def get_bounding_box(ground_truth_map):
    # get bounding box from mask
    y_indices, x_indices = np.where(ground_truth_map > 0)
    x_min, x_max = np.min(x_indices), np.max(x_indices)
    y_min, y_max = np.min(y_indices), np.max(y_indices)
    # add perturbation to bounding box coordinates
    H, W = ground_truth_map.shape
    x_min = max(0, x_min - np.random.randint(0, 20))
    x_max = min(W, x_max + np.random.randint(0, 20))
    y_min = max(0, y_min - np.random.randint(0, 20))
    y_max = min(H, y_max + np.random.randint(0, 20))
    bbox = [x_min, y_min, x_max, y_max]

    return bbox

input_boxes = get_bounding_box(ground_truth_seg)
input_boxes
# Out:
# [27, 34, 228, 210]

# %%
import matplotlib.pyplot as plt

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

def show_boxes_on_image(raw_image, boxes):
    plt.figure(figsize=(6,6))
    plt.imshow(raw_image)
    for box in boxes:
        show_box(box, plt.gca())
    plt.axis('on')
    plt.show()

# %%
show_boxes_on_image(image, [input_boxes])

# %%
print([input_boxes][0])
# Out:
# [27, 34, 228, 210]

# %%
# expanded_image = np.expand_dims(image, axis=2)
# expanded_image = np.tile(expanded_image, (1, 1, 3))

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# prepare image + box prompt for the model
inputs = processor(image, input_boxes=[[input_boxes]], return_tensors="pt").to(device)
for k,v in inputs.items():
    print(k,v.shape)
# Out:
# pixel_values torch.Size([1, 3, 1024, 1024])
# original_sizes torch.Size([1, 2])
# reshaped_input_sizes torch.Size([1, 2])
# input_boxes torch.Size([1, 1, 4])

# %%
model.to(device)

# forward pass
# note that the authors use `multimask_output=False` when performing inference
with torch.no_grad():
    outputs = model(**inputs, multimask_output=False)

# %%
outputs.pred_masks.shape
# Out:
# torch.Size([1, 1, 1, 256, 256])

# %%
# apply sigmoid
medsam_seg_prob = torch.sigmoid(outputs.pred_masks.squeeze(1))
# convert soft mask to hard mask
medsam_seg_prob = medsam_seg_prob.cpu().numpy().squeeze()
medsam_seg = (medsam_seg_prob > 0.5).astype(np.uint8)

# %% [markdown]
# # Visualize

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

fig, axes = plt.subplots()

axes.imshow(np.array(image))
show_mask(medsam_seg, axes)
axes.title.set_text(f"Predicted mask")
axes.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
fig, axes = plt.subplots()
axes.imshow(np.array(np.zeros_like(image)))
show_mask(medsam_seg, axes)

# %%
fig, axes = plt.subplots()

axes.imshow(np.array(image))
show_mask(ground_truth_seg, axes)
axes.title.set_text(f"Ground truth mask")
axes.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
fig, axes = plt.subplots()
axes.imshow(np.array(np.zeros_like(image)))
show_mask(ground_truth_seg, axes)

# %%
print(f"mIOU of two same masks are {compute_iou(medsam_seg, ground_truth_seg)}")
# Out:
# mIOU of two same masks are 0.75

# %%
print(f"Dice Coefficient of two same masks are {DICE_COE(medsam_seg, ground_truth_seg)}")
# Out:
# Dice Coefficient of two same masks are 1.55

# %%
print(f"Mean Pixel Accuracy of two same masks are {mean_pixel_accuracy(medsam_seg, ground_truth_seg)}")
# Out:
# Mean Pixel Accuracy of two same masks are 0.0

# %% [markdown]
# # Create image dataset

# %%
from datasets import Dataset, Image

def create_dataset(images, labels):
    dataset = Dataset.from_dict({"image": images,
                                "label": labels})
    dataset = dataset.cast_column("image", Image())
    dataset = dataset.cast_column("label", Image())

    return dataset

# %%
# load original data hosted on Google Drive
# result = np.load("/content/drive/MyDrive/MedSAM/Dummy data/22-2D-Images/01-US_Breast_Cancer.npz")

# dataset = create_dataset(images=result["imgs"], labels=result["gts"])

# %%
dataset
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 130
# })

# %%
dataset[0]["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
np.unique(np.array(dataset[0]["label"]))
# Out:
# array([0, 1], dtype=int32)

# %%
# !pip install huggingface_hub -U -q
# Out:
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (0.16.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface_hub) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2023.5.7)

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# dataset.push_to_hub("PushkarA07/breast-cancer")
